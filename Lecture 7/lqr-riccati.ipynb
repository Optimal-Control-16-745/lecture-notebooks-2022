# %%
import Pkg; Pkg.activate(@__DIR__); Pkg.instantiate()
# Out:
#   Activating environment at `~/GitHub/lecture-notebooks/Lecture 7/Project.toml`

# %%
using LinearAlgebra
using PyPlot
using ControlSystems

# %%
# Discrete dynamics
h = 0.1   # time step
A = [1 h; 0 1]
B = [0.5*h*h; h]
# Out:
# 2-element Vector{Float64}:
#  0.005000000000000001
#  0.1

# %%
n = 2     # number of state
m = 1     # number of controls
Tfinal = 100.0 # final time
N = Int(Tfinal/h)+1    # number of time steps
thist = Array(range(0,h*(N-1), step=h));

# %%
# Initial conditions
x0 = [1.0; 0]
# Out:
# 2-element Vector{Float64}:
#  1.0
#  0.0

# %%
# Cost weights
Q = Array(1.0*I(2))
R = 0.1 #Array(1.0*I(1))
Qn = Array(1.0*I(2))
# Out:
# 2×2 Matrix{Float64}:
#  1.0  0.0
#  0.0  1.0

# %%
#Cost function
function J(xhist,uhist)
    cost = 0.5*xhist[:,end]'*Qn*xhist[:,end]
    for k = 1:(N-1)
        cost = cost + 0.5*xhist[:,k]'*Q*xhist[:,k] + 0.5*(uhist[k]'*R*uhist[k])[1]
    end
    return cost
end
# Out:
# J (generic function with 1 method)

# %%
P = zeros(n,n,N)
K = zeros(m,n,N-1)

P[:,:,N] .= Qn

#Backward Riccati recursion
for k = (N-1):-1:1
    K[:,:,k] .= (R + B'*P[:,:,k+1]*B)\(B'*P[:,:,k+1]*A)
    P[:,:,k] .= Q + A'*P[:,:,k+1]*(A-B*K[:,:,k])
end

#Forward rollout starting at x0
xhist = zeros(n,N)
xhist[:,1] = x0
uhist = zeros(m,N-1)
for k = 1:(N-1)
    uhist[:,k] .= -K[:,:,k]*xhist[:,k]
    xhist[:,k+1] .= A*xhist[:,k] + B*uhist[k]
end

# %%
# Plot x1 vs. x2, u vs. t, x vs. t, etc.
times = range(0,h*(N-1), step=h)
plot(times,xhist[1,:], label="position")
plot(times,xhist[2,:], label="velocity")
xlabel("time")
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x1964d1490>

# %%
plot(times[1:end-1], uhist[1,:], label="control")
xlabel("Time")
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x19655b550>

# %%
J(xhist,uhist)
# Out:
# 6.658612220565542

# %%
#Forward rollout with random noise
xhist = zeros(n,N)
xhist[:,1] = x0 #10.0*randn(2) #Can start anywhere
uhist = zeros(m,N-1)
for k = 1:(N-1)
    uhist[:,k] .= -K[:,:,k]*xhist[:,k]
    xhist[:,k+1] .= A*xhist[:,k] + B*uhist[k] + 0.01*randn(2) #can add noise to dynamics
end

# %%
plot(K[1,1,:], label="K1")
plot(K[1,2,:], label="K2")
xlabel("time")
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x19644ba60>

# %%
#Compute infinite-horizon K matrix using ControlSystems.jl
Kinf = dlqr(A,B,Q,R)
#Compare to ours
K[:,:,1]-Kinf
# Out:
# 1×2 Matrix{Float64}:
#  3.59712e-14  4.88498e-15

# %%
#Forward rollout with constant K
xhist = zeros(n,N)
xhist[:,1] = x0 #Can start anywhere
uhist = zeros(m,N-1)
for k = 1:(N-1)
    uhist[:,k] .= -Kinf*xhist[:,k]
    xhist[:,k+1] .= A*xhist[:,k] + B*uhist[k] #+ 0.01*randn(2)
end

# %%
#Closed-loop Eigenvalues
eigvals(A-B*Kinf)
# Out:
# 2-element Vector{Float64}:
#  0.743557597843391
#  0.8991703058887761
